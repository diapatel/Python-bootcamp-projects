# %%
import random

word_list = ['aadvark', 'baboon', 'camel']
chosen_word = random.choice(word_list)
print(chosen_word)

end_of_game = False

stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']


#guess = input("Guess a letter: ").lower()

# if guess in chosen_word:
#     print('Yes')
    
display = []
lives = len(chosen_word)

for char in chosen_word:
    display += '_'

print(display)


while end_of_game == False:
    
    
    guess = input("Guess a letter: ").lower()
    stage = 0
    for position in range(len(chosen_word)):
        letter = chosen_word[position]
        if letter == guess:
            display[position] = letter
    
    if guess not in chosen_word:
        print("You've chosen a wrong letter. you lose a life.")
        lives -= 1
        print(stages[lives])
        
    if '_' not in display or lives == 0:
        end_of_game = True
        print('YOU LOSE.')

    print(display)
print('You\'ve won')

# if '_' not in display or lives == 0:
#     end_of_game = True
#     print('YOU LOSE.')
# Out:
# baboon
# ['_', '_', '_', '_', '_', '_']
# Guess a letter: a
# ['_', 'a', '_', '_', '_', '_']
# Guess a letter: b
# ['b', 'a', 'b', '_', '_', '_']
# Guess a letter: s
# You've chosen a wrong letter. you lose a life.
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# ['b', 'a', 'b', '_', '_', '_']
# Guess a letter: c
# You've chosen a wrong letter. you lose a life.
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
#
# ['b', 'a', 'b', '_', '_', '_']
# Guess a letter: d
# You've chosen a wrong letter. you lose a life.
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# ['b', 'a', 'b', '_', '_', '_']
# Guess a letter: l
# You've chosen a wrong letter. you lose a life.
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# =========
#
# ['b', 'a', 'b', '_', '_', '_']
# Guess a letter: b
# ['b', 'a', 'b', '_', '_', '_']
# Guess a letter: o
# ['b', 'a', 'b', 'o', 'o', '_']
# Guess a letter: n
# YOU LOSE.
# ['b', 'a', 'b', 'o', 'o', 'n']
# You've won

# %%
list_ = ['a', 'b', 'c']
print(list_.index('a'))
# Out:
# 0
